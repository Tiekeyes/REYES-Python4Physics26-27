# %% [markdown]
# Functions Project

# %%
import numpy as np

#gravity
g = (9.8) #m/s^-2

#mass, velocity, height
m = float(input("How heavy is the object? ")) #kg
v = float(input("How fast is the object intially going? ")) #m/s
h = float(input("What height is the object located initially? ")) #m

#Kinetic Energy
KE = (1/2) * m * (v**2) #Joules

#Gravitational Potential Energy
UE = m * g * h


#returns total energy
def total_energy():
    return KE + UE

print("The total energy in joules is: " + str(total_energy()))
# Out:
# The total energy in joules is: 1480.0

# %%
import numpy as np

#create an array of zeros one by two 
my_array = np.zeros([2, 1])

#print the row and column size of my_array
print(np.shape(my_array))

print(my_array)
# Out:
# (2, 1)
# [[0.]
#  [0.]]
